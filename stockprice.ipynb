# %% [markdown]
# <a href="https://colab.research.google.com/github/will42mcd/CS-6000/blob/main/stockprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
amzn = pd.read_csv('/content/drive/MyDrive/prim_6000/Amazon_HistoricalData.csv')
amzn_df = pd.DataFrame(amzn)
amzn
# Out:
#             Date Close/Last    Volume      Open       High       Low
# 0     09/29/2023    $127.12  62411730   $128.20    $129.15   $126.32
# 1     09/28/2023    $125.98  54554970   $124.04  $126.5801   $123.04
# 2     09/27/2023    $125.98  66553450   $125.76    $127.48   $124.13
# 3     09/26/2023    $125.98  73048210   $130.12    $130.39   $125.28
# 4     09/25/2023    $131.27  46017830   $129.36    $131.78   $128.77
# ...          ...        ...       ...       ...        ...       ...
# 2513  10/04/2013    $15.952  36299520  $15.7565     $15.96   $15.631
# 2514  10/03/2013    $15.738  53494820  $16.0195    $16.146   $15.651
# 2515  10/02/2013   $16.0255  44347460   $15.902   $16.0865   $15.876
# 2516  10/01/2013   $16.0475  47926460   $15.711     $16.05  $15.6825
# 2517  09/30/2013    $15.632  32449520  $15.6705   $15.7655   $15.553
#
# [2518 rows x 6 columns]

# %%
amd = pd.read_csv('/content/drive/MyDrive/prim_6000/AMD_HistoricalData.csv')
amd_df = pd.DataFrame(amd)
amd
# Out:
#             Date Close/Last    Volume     Open     High      Low
# 0     09/29/2023    $102.82  56078640  $104.69  $104.94  $102.56
# 1     09/28/2023    $102.76  72542060   $97.94  $104.20   $97.76
# 2     09/27/2023     $98.07  51261500   $96.82   $99.23   $96.35
# 3     09/26/2023     $95.96  42866460   $96.50   $97.83   $95.27
# 4     09/25/2023     $97.38  43223750   $95.95   $97.45   $94.46
# ...          ...        ...       ...      ...      ...      ...
# 2513  10/04/2013      $3.91  17112130    $3.91    $3.95    $3.89
# 2514  10/03/2013      $3.90  25488340    $3.93    $3.94    $3.86
# 2515  10/02/2013      $3.90  18561830    $3.83    $3.94    $3.82
# 2516  10/01/2013      $3.86  26000870    $3.82    $3.94    $3.81
# 2517  09/30/2013      $3.81  16543420    $3.79    $3.86    $3.75
#
# [2518 rows x 6 columns]

# %%
tsla = pd.read_csv('/content/drive/MyDrive/prim_6000/Tesla_HistoricalData.csv')
tsla_df = pd.DataFrame(tsla)
tsla_df
# Out:
#             Date Close/Last     Volume      Open      High        Low
# 0     09/29/2023    $250.22  128522700   $250.00   $254.77    $246.35
# 1     09/28/2023    $246.38  117058900   $240.02   $247.55    $238.65
# 2     09/27/2023    $240.50  136597200  $244.262   $245.33    $234.58
# 3     09/26/2023    $244.12  101993600   $242.98   $249.55  $241.6601
# 4     09/25/2023    $246.99  104636600   $243.38   $247.10    $238.31
# ...          ...        ...        ...       ...       ...        ...
# 2513  10/04/2013   $12.0653  215514642    $11.76  $12.0787     $11.51
# 2514  10/03/2013    $11.554  356474372  $11.6697  $11.9793     $11.20
# 2515  10/02/2013   $12.0633  310766545  $12.5727  $12.7887   $11.6933
# 2516  10/01/2013   $12.8667  116320352  $12.9307  $12.9487    $12.558
# 2517  09/30/2013   $12.8913  133849178    $12.60  $12.9667   $12.5333
#
# [2518 rows x 6 columns]

# %%
nflx = pd.read_csv('/content/drive/MyDrive/prim_6000/Netflix_HistoricalData.csv')
nflx_df = pd.DataFrame(nflx)
nflx_df
# Out:
#             Date Close/Last    Volume      Open      High       Low
# 0     09/29/2023    $377.60   4205298   $380.00   $382.58   $375.35
# 1     09/28/2023    $376.36   4369906   $375.60   $378.96   $371.10
# 2     09/27/2023    $377.59   3843521   $382.40  $384.223   $376.25
# 3     09/26/2023    $379.25   4089392   $382.88   $384.56  $377.355
# 4     09/25/2023    $384.80   3757278   $382.90   $386.62   $380.81
# ...          ...        ...       ...       ...       ...       ...
# 2513  10/04/2013   $46.7514  16813088    $46.24    $46.90  $45.5057
# 2514  10/03/2013     $45.96  24602536  $47.2871  $47.7857  $45.4357
# 2515  10/02/2013   $47.2471  30583205  $46.0128  $47.6571  $45.9457
# 2516  10/01/2013   $46.3743  29684286  $44.9671  $46.3857  $44.8571
# 2517  09/30/2013   $44.1728  12528604    $43.96  $44.5928    $43.60
#
# [2518 rows x 6 columns]
