# %% [markdown]
# <a href="https://colab.research.google.com/github/will42mcd/CS-6000/blob/main/OptionsPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import yfinance as yf

def options_chain_msft(symbol):

    tk = yf.Ticker("MSFT")
    exps = tk.options

    options = pd.DataFrame()
    for e in exps:
        opt = tk.option_chain(e)
        opt = pd.DataFrame().append(opt.calls).append(opt.puts)
        opt['expirationDate'] = e
        options = options.append(opt, ignore_index=True)

    options['CALL'] = options['contractSymbol'].str[4:].apply(
        lambda x: "C" in x)

    options[['bid', 'ask', 'strike']] = options[['bid', 'ask', 'strike']].apply(pd.to_numeric)
    options['mark'] = (options['bid'] + options['ask']) / 2

    options = options.drop(columns = ['contractSize', 'currency', 'change', 'percentChange', 'lastTradeDate', 'lastPrice'])

    return options

options_chain_msft("MSFT")
# Out:
# <ipython-input-1-a4f05001dc94>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-1-a4f05001dc94>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# <ipython-input-1-a4f05001dc94>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-1-a4f05001dc94>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# ...

# %%
def options_chain_amzn(symbol):

    tk = yf.Ticker("AMZN")
    exps = tk.options

    options = pd.DataFrame()
    for e in exps:
        opt = tk.option_chain(e)
        opt = pd.DataFrame().append(opt.calls).append(opt.puts)
        opt['expirationDate'] = e
        options = options.append(opt, ignore_index=True)

    options['CALL'] = options['contractSymbol'].str[4:].apply(
        lambda x: "C" in x)

    options[['bid', 'ask', 'strike']] = options[['bid', 'ask', 'strike']].apply(pd.to_numeric)
    options['mark'] = (options['bid'] + options['ask']) / 2

    options = options.drop(columns = ['contractSize', 'currency', 'change', 'percentChange', 'lastTradeDate', 'lastPrice'])

    return options

options_chain_amzn("AMZN")
# Out:
# <ipython-input-2-d5a91c0b8e73>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-2-d5a91c0b8e73>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# <ipython-input-2-d5a91c0b8e73>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-2-d5a91c0b8e73>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# ...

# %%
def options_chain_amd(symbol):

    tk = yf.Ticker("AMD")
    exps = tk.options

    options = pd.DataFrame()
    for e in exps:
        opt = tk.option_chain(e)
        opt = pd.DataFrame().append(opt.calls).append(opt.puts)
        opt['expirationDate'] = e
        options = options.append(opt, ignore_index=True)

    options['CALL'] = options['contractSymbol'].str[4:].apply(
        lambda x: "C" in x)

    options[['bid', 'ask', 'strike']] = options[['bid', 'ask', 'strike']].apply(pd.to_numeric)
    options['mark'] = (options['bid'] + options['ask']) / 2

    options = options.drop(columns = ['contractSize', 'currency', 'change', 'percentChange', 'lastTradeDate', 'lastPrice'])

    return options

options_chain_amd("AMD")
# Out:
# <ipython-input-3-8aa2227f0198>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-3-8aa2227f0198>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# <ipython-input-3-8aa2227f0198>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-3-8aa2227f0198>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# ...

# %%
def options_chain_tsla(symbol):

    tk = yf.Ticker("TSLA")
    exps = tk.options

    options = pd.DataFrame()
    for e in exps:
        opt = tk.option_chain(e)
        opt = pd.DataFrame().append(opt.calls).append(opt.puts)
        opt['expirationDate'] = e
        options = options.append(opt, ignore_index=True)

    options['CALL'] = options['contractSymbol'].str[4:].apply(
        lambda x: "C" in x)

    options[['bid', 'ask', 'strike']] = options[['bid', 'ask', 'strike']].apply(pd.to_numeric)
    options['mark'] = (options['bid'] + options['ask']) / 2

    options = options.drop(columns = ['contractSize', 'currency', 'change', 'percentChange', 'lastTradeDate', 'lastPrice'])

    return options

options_chain_tsla("TSLA")
# Out:
# <ipython-input-4-bfc7b55fde25>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-4-bfc7b55fde25>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# <ipython-input-4-bfc7b55fde25>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-4-bfc7b55fde25>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# ...

# %%
def options_chain_nflx(symbol):

    tk = yf.Ticker("NFLX")
    exps = tk.options

    options = pd.DataFrame()
    for e in exps:
        opt = tk.option_chain(e)
        opt = pd.DataFrame().append(opt.calls).append(opt.puts)
        opt['expirationDate'] = e
        options = options.append(opt, ignore_index=True)

    options['CALL'] = options['contractSymbol'].str[4:].apply(
        lambda x: "C" in x)

    options[['bid', 'ask', 'strike']] = options[['bid', 'ask', 'strike']].apply(pd.to_numeric)
    options['mark'] = (options['bid'] + options['ask']) / 2

    options = options.drop(columns = ['contractSize', 'currency', 'change', 'percentChange', 'lastTradeDate', 'lastPrice'])

    return options

options_chain_nflx("NFLX")
# Out:
# <ipython-input-5-887a814dc3f1>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-5-887a814dc3f1>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# <ipython-input-5-887a814dc3f1>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   opt = pd.DataFrame().append(opt.calls).append(opt.puts)
# <ipython-input-5-887a814dc3f1>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   options = options.append(opt, ignore_index=True)
# ...
